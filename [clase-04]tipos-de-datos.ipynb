# %% [markdown]
# # Tipos de datos en estadística inferencial
#
# Aquí tenemos en cuenta los diferentes tipos de datos o variables estructuradas en cualquier problema de ciencia de datos.
#
# * datos categóricos: ordinales y nominales
# * datos numéricos: discretos y continuos
#
# a continuación exploraremos un dataset que contiene todos estos tipos de datos: https://www.kaggle.com/lepchenkov/usedcarscatalog

# %%
import pandas as pd

df = pd.read_csv('cars.csv')

df.head().style.background_gradient(cmap = 'coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_00136_row0_col4 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_00136_row0_col5, #T_00136_row1_col5, #T_00136_row2_col5, #T_00136_row2_col14, #T_00136_row3_col5, #T_00136_row4_col5, #T_00136_row4_col14 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_00136_row0_col9, #T_00136_row0_col17, #T_00136_row0_col18, #T_00136_row0_col29, #T_00136_row1_col9, #T_00136_row1_col17, #T_00136_row1_col18, #T_00136_row1_col29, #T_00136_row2_col9, #T_00136_row2_col17, #T_00136_row2_col18, #T_00136_row2_col29, #T_00136_row3_col9, #T_00136_row3_col17, #T_00136_row3_col18, #T_00136_row3_col29, #T_00136_row4_col9, #T_00136_row4_col17, #T_00136_row4_col18, #T_00136_row4_col29 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_00136_row0_col14, #T_00136_row3_col4, #T_00136_row3_col14 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_00136_row1_col4 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_00136_row1_col14 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_00136_row2_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_00136_row4_col4 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# </style>
# <table id="T_00136">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00136_level0_col0" class="col_heading level0 col0" >manufacturer_name</th>
#       <th id="T_00136_level0_col1" class="col_heading level0 col1" >model_name</th>
#       <th id="T_00136_level0_col2" class="col_heading level0 col2" >transmission</th>
#       <th id="T_00136_level0_col3" class="col_heading level0 col3" >color</th>
#       <th id="T_00136_level0_col4" class="col_heading level0 col4" >odometer_value</th>
#       <th id="T_00136_level0_col5" class="col_heading level0 col5" >year_produced</th>
#       <th id="T_00136_level0_col6" class="col_heading level0 col6" >engine_fuel</th>
#       <th id="T_00136_level0_col7" class="col_heading level0 col7" >engine_has_gas</th>
#       <th id="T_00136_level0_col8" class="col_heading level0 col8" >engine_type</th>
#       <th id="T_00136_level0_col9" class="col_heading level0 col9" >engine_capacity</th>
#       <th id="T_00136_level0_col10" class="col_heading level0 col10" >body_type</th>
#       <th id="T_00136_level0_col11" class="col_heading level0 col11" >has_warranty</th>
#       <th id="T_00136_level0_col12" class="col_heading level0 col12" >state</th>
#       <th id="T_00136_level0_col13" class="col_heading level0 col13" >drivetrain</th>
#       <th id="T_00136_level0_col14" class="col_heading level0 col14" >price_usd</th>
#       <th id="T_00136_level0_col15" class="col_heading level0 col15" >is_exchangeable</th>
#       <th id="T_00136_level0_col16" class="col_heading level0 col16" >location_region</th>
#       <th id="T_00136_level0_col17" class="col_heading level0 col17" >number_of_photos</th>
#       <th id="T_00136_level0_col18" class="col_heading level0 col18" >up_counter</th>
#       <th id="T_00136_level0_col19" class="col_heading level0 col19" >feature_0</th>
#       <th id="T_00136_level0_col20" class="col_heading level0 col20" >feature_1</th>
#       <th id="T_00136_level0_col21" class="col_heading level0 col21" >feature_2</th>
#       <th id="T_00136_level0_col22" class="col_heading level0 col22" >feature_3</th>
#       <th id="T_00136_level0_col23" class="col_heading level0 col23" >feature_4</th>
#       <th id="T_00136_level0_col24" class="col_heading level0 col24" >feature_5</th>
#       <th id="T_00136_level0_col25" class="col_heading level0 col25" >feature_6</th>
#       <th id="T_00136_level0_col26" class="col_heading level0 col26" >feature_7</th>
#       <th id="T_00136_level0_col27" class="col_heading level0 col27" >feature_8</th>
#       <th id="T_00136_level0_col28" class="col_heading level0 col28" >feature_9</th>
#       <th id="T_00136_level0_col29" class="col_heading level0 col29" >duration_listed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00136_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00136_row0_col0" class="data row0 col0" >Subaru</td>
#       <td id="T_00136_row0_col1" class="data row0 col1" >Outback</td>
#       <td id="T_00136_row0_col2" class="data row0 col2" >automatic</td>
#       <td id="T_00136_row0_col3" class="data row0 col3" >silver</td>
#       <td id="T_00136_row0_col4" class="data row0 col4" >190000</td>
#       <td id="T_00136_row0_col5" class="data row0 col5" >2010</td>
#       <td id="T_00136_row0_col6" class="data row0 col6" >gasoline</td>
#       <td id="T_00136_row0_col7" class="data row0 col7" >False</td>
#       <td id="T_00136_row0_col8" class="data row0 col8" >gasoline</td>
#       <td id="T_00136_row0_col9" class="data row0 col9" >2.500000</td>
#       <td id="T_00136_row0_col10" class="data row0 col10" >universal</td>
#       <td id="T_00136_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_00136_row0_col12" class="data row0 col12" >owned</td>
#       <td id="T_00136_row0_col13" class="data row0 col13" >all</td>
#       <td id="T_00136_row0_col14" class="data row0 col14" >10900.000000</td>
#       <td id="T_00136_row0_col15" class="data row0 col15" >False</td>
#       <td id="T_00136_row0_col16" class="data row0 col16" >Минская обл.</td>
#       <td id="T_00136_row0_col17" class="data row0 col17" >9</td>
#       <td id="T_00136_row0_col18" class="data row0 col18" >13</td>
#       <td id="T_00136_row0_col19" class="data row0 col19" >False</td>
#       <td id="T_00136_row0_col20" class="data row0 col20" >True</td>
#       <td id="T_00136_row0_col21" class="data row0 col21" >True</td>
#       <td id="T_00136_row0_col22" class="data row0 col22" >True</td>
#       <td id="T_00136_row0_col23" class="data row0 col23" >False</td>
#       <td id="T_00136_row0_col24" class="data row0 col24" >True</td>
#       <td id="T_00136_row0_col25" class="data row0 col25" >False</td>
#       <td id="T_00136_row0_col26" class="data row0 col26" >True</td>
#       <td id="T_00136_row0_col27" class="data row0 col27" >True</td>
#       <td id="T_00136_row0_col28" class="data row0 col28" >True</td>
#       <td id="T_00136_row0_col29" class="data row0 col29" >16</td>
#     </tr>
#     <tr>
#       <th id="T_00136_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00136_row1_col0" class="data row1 col0" >Subaru</td>
#       <td id="T_00136_row1_col1" class="data row1 col1" >Outback</td>
#       <td id="T_00136_row1_col2" class="data row1 col2" >automatic</td>
#       <td id="T_00136_row1_col3" class="data row1 col3" >blue</td>
#       <td id="T_00136_row1_col4" class="data row1 col4" >290000</td>
#       <td id="T_00136_row1_col5" class="data row1 col5" >2002</td>
#       <td id="T_00136_row1_col6" class="data row1 col6" >gasoline</td>
#       <td id="T_00136_row1_col7" class="data row1 col7" >False</td>
#       <td id="T_00136_row1_col8" class="data row1 col8" >gasoline</td>
#       <td id="T_00136_row1_col9" class="data row1 col9" >3.000000</td>
#       <td id="T_00136_row1_col10" class="data row1 col10" >universal</td>
#       <td id="T_00136_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_00136_row1_col12" class="data row1 col12" >owned</td>
#       <td id="T_00136_row1_col13" class="data row1 col13" >all</td>
#       <td id="T_00136_row1_col14" class="data row1 col14" >5000.000000</td>
#       <td id="T_00136_row1_col15" class="data row1 col15" >True</td>
#       <td id="T_00136_row1_col16" class="data row1 col16" >Минская обл.</td>
#       <td id="T_00136_row1_col17" class="data row1 col17" >12</td>
#       <td id="T_00136_row1_col18" class="data row1 col18" >54</td>
#       <td id="T_00136_row1_col19" class="data row1 col19" >False</td>
#       <td id="T_00136_row1_col20" class="data row1 col20" >True</td>
#       <td id="T_00136_row1_col21" class="data row1 col21" >False</td>
#       <td id="T_00136_row1_col22" class="data row1 col22" >False</td>
#       <td id="T_00136_row1_col23" class="data row1 col23" >True</td>
#       <td id="T_00136_row1_col24" class="data row1 col24" >True</td>
#       <td id="T_00136_row1_col25" class="data row1 col25" >False</td>
#       <td id="T_00136_row1_col26" class="data row1

# %% [markdown]
# los tipos de datos de cada columna en el dataset se pueden obtener directamente con `pandas.DataFrame.dtypes`
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html

# %%
df.dtypes
# Out:
# manufacturer_name     object
# model_name            object
# transmission          object
# color                 object
# odometer_value         int64
# year_produced          int64
# engine_fuel           object
# engine_has_gas          bool
# engine_type           object
# engine_capacity      float64
# body_type             object
# has_warranty            bool
# state                 object
# drivetrain            object
# price_usd            float64
# is_exchangeable         bool
# location_region       object
# number_of_photos       int64
# up_counter             int64
# feature_0               bool
# feature_1               bool
# feature_2               bool
# feature_3               bool
# feature_4               bool
# feature_5               bool
# feature_6               bool
# feature_7               bool
# feature_8               bool
# feature_9               bool
# duration_listed        int64
# dtype: object

# %% [markdown]
# Aquí vemos que los tipos de datos se identifican de la siguiente manera:
#
# * Categoricos: `object`, `bool`
# * Numéricos: `int64` (discreto), `float64` (contínuo)

# %% [markdown]
# Ahora, con la libreria pandas podemos generar un conjunto completo de estadisticos descriptivos del dataset usando `pandas.DataFrame.describe()`
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html

# %%
df.describe().style.background_gradient(cmap = 'coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_55fd0_row0_col0, #T_55fd0_row0_col1, #T_55fd0_row0_col2, #T_55fd0_row0_col3, #T_55fd0_row0_col4, #T_55fd0_row0_col5, #T_55fd0_row0_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_55fd0_row1_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_55fd0_row1_col1, #T_55fd0_row1_col2, #T_55fd0_row1_col4, #T_55fd0_row1_col5, #T_55fd0_row1_col6, #T_55fd0_row2_col1, #T_55fd0_row2_col2, #T_55fd0_row2_col4, #T_55fd0_row2_col5, #T_55fd0_row2_col6, #T_55fd0_row3_col0, #T_55fd0_row3_col1, #T_55fd0_row3_col2, #T_55fd0_row3_col3, #T_55fd0_row3_col4, #T_55fd0_row3_col5, #T_55fd0_row3_col6, #T_55fd0_row4_col1, #T_55fd0_row4_col2, #T_55fd0_row4_col3, #T_55fd0_row4_col4, #T_55fd0_row4_col5, #T_55fd0_row4_col6, #T_55fd0_row5_col1, #T_55fd0_row5_col2, #T_55fd0_row5_col4, #T_55fd0_row5_col5, #T_55fd0_row5_col6, #T_55fd0_row6_col1, #T_55fd0_row6_col2, #T_55fd0_row6_col4, #T_55fd0_row6_col5, #T_55fd0_row6_col6, #T_55fd0_row7_col1, #T_55fd0_row7_col2, #T_55fd0_row7_col4, #T_55fd0_row7_col5, #T_55fd0_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_55fd0_row1_col3, #T_55fd0_row2_col3, #T_55fd0_row5_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_55fd0_row2_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_55fd0_row4_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_55fd0_row5_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_55fd0_row6_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_55fd0_row6_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_55fd0_row7_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_55fd0_row7_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_55fd0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55fd0_level0_col0" class="col_heading level0 col0" >odometer_value</th>
#       <th id="T_55fd0_level0_col1" class="col_heading level0 col1" >year_produced</th>
#       <th id="T_55fd0_level0_col2" class="col_heading level0 col2" >engine_capacity</th>
#       <th id="T_55fd0_level0_col3" class="col_heading level0 col3" >price_usd</th>
#       <th id="T_55fd0_level0_col4" class="col_heading level0 col4" >number_of_photos</th>
#       <th id="T_55fd0_level0_col5" class="col_heading level0 col5" >up_counter</th>
#       <th id="T_55fd0_level0_col6" class="col_heading level0 col6" >duration_listed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55fd0_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_55fd0_row0_col0" class="data row0 col0" >38531.000000</td>
#       <td id="T_55fd0_row0_col1" class="data row0 col1" >38531.000000</td>
#       <td id="T_55fd0_row0_col2" class="data row0 col2" >38521.000000</td>
#       <td id="T_55fd0_row0_col3" class="data row0 col3" >38531.000000</td>
#       <td id="T_55fd0_row0_col4" class="data row0 col4" >38531.000000</td>
#       <td id="T_55fd0_row0_col5" class="data row0 col5" >38531.000000</td>
#       <td id="T_55fd0_row0_col6" class="data row0 col6" >38531.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55fd0_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_55fd0_row1_col0" class="data row1 col0" >248864.638447</td>
#       <td id="T_55fd0_row1_col1" class="data row1 col1" >2002.943734</td>
#       <td id="T_55fd0_row1_col2" class="data row1 col2" >2.055161</td>
#       <td id="T_55fd0_row1_col3" class="data row1 col3" >6639.971021</td>
#       <td id="T_55fd0_row1_col4" class="data row1 col4" >9.649062</td>
#       <td id="T_55fd0_row1_col5" class="data row1 col5" >16.306091</td>
#       <td id="T_55fd0_row1_col6" class="data row1 col6" >80.577249</td>
#     </tr>
#     <tr>
#       <th id="T_55fd0_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_55fd0_row2_col0" class="data row2 col0" >136072.376530</td>
#       <td id="T_55fd0_row2_col1" class="data row2 col1" >8.065731</td>
#       <td id="T_55fd0_row2_col2" class="data row2 col2" >0.671178</td>
#       <td id="T_55fd0_row2_col3" class="data row2 col3" >6428.152018</td>
#       <td id="T_55fd0_row2_col4" class="data row2 col4" >6.093217</td>
#       <td id="T_55fd0_row2_col5" class="data row2 col5" >43.286933</td>
#       <td id="T_55fd0_row2_col6" class="data row2 col6" >112.826569</td>
#     </tr>
#     <tr>
#       <th id="T_55fd0_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_55fd0_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_55fd0_row3_col1" class="data row3 col1" >1942.000000</td>
#       <td id="T_55fd0_row3_col2" class="data row3 col2" >0.200000</td>
#       <td id="T_55fd0_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_55fd0_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_55fd0_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_55fd0_row3_col6" class="data row3 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55fd0_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_55fd0_row4_col0" class="data row4 col0" >158000.000000</td>
#       <td id="T_55fd0_row4_col1" class="data row4 col1" >1998.000000</td>
#       <td id="T_55fd0_row4_col2" class="data row4 col2" >1.600000</td>
#       <td id="T_55fd0_row4_col3" class="data row4 col3" >2100.000000</td>
#       <td id="T_55fd0_row4_col4" class="data row4 col4" >5.000000</td>
#       <td id="T_55fd0_row4_col5" class="data row4 col5" >2.000000</td>
#       <td id="T_55fd0_row4_col6" class="data row4 col6" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55fd0_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_55fd0_row5_col0" class="data row5 col0" >250000.000000</td>
#       <td id="T_55fd0_row5_col1" class="data row5 col1" >2003.000000</td>
#       <td id="T_55fd0_row5_col2" class="data row5 col2" >2.000000</td>
#       <td id="T_55fd0_row5_col3" class="data row5 col3" >4800.000000</td>
#       <td id="T_55fd0_row5_col4" class="data row5 col4" >8.000000</td>
#       <td id="T_55fd0_row5_col5" class="data row5 col5" >5.000000</td>
#       <td id="T_55fd0_row5_col6" class="data row5 col6" >59.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55fd0_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_55fd0_row6_col0" class="data row6 col0" >325000.000000</td>
#       <td id="T_55fd0_row6_col1" class="data row6 col1" >2009.000000</td>
#       <td id="T_55fd0_row6_col2" class="data row6 col2" >2.300000</td>
#       <td id="T_55fd0_row6_col3" class="data row6 col3" >8990.000000</td>
#       <td id="T_55fd0_row6_col4" class="data row6 col4" >12.000000</td>
#       <td id="T_55fd0_row6_col5" class="data row6 col5" >16.000000</td>
#       <td id="T_55fd0_row6_col6" class="data row6 col6" >91.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55fd0_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_55fd0_row7_col0" class="data row7 col0" >1000000.000000</td>
#       <td id="T_55fd0_row7_col1" class="data row7 col1" >2019.000000</td>
#       <td id="T_55fd0_row7_col2" class="data row7 col2" >8.000000</td>
#       <td id="T_55fd0_row7_col3" class="data row7 col3" >50000.000000</td>
#       <td id="T_55fd0_row7_col4" class="data row7 col4" >86.000000</td>
#       <td id="T_55fd0_row7_col5" class="data row7 col5" >1861.000000</td>
#       <td id="T_55fd0_row7_col6" class="data row7 col6" >2232.000000</td>
#     </tr>
#   </tbody>
# </table>
