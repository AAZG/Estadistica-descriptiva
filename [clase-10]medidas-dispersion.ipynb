# %% [markdown]
# # Medidas de dispersión
#
# continuamos con el dataset https://www.kaggle.com/lepchenkov/usedcarscatalog

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

df = pd.read_csv('cars.csv')

# %%
# Desviación estandar
df['price_usd'].std()
# Out:
# 6428.1520182029035

# %%
# Rango = valor max - valor min
rango = df['price_usd'].max() - df['price_usd'].min()
rango
# Out:
# 49999.0

# %%
median = df['price_usd'].median()

Q1 = df['price_usd'].quantile(q=0.25)
Q3 = df['price_usd'].quantile(q=0.75)

min_val = df['price_usd'].quantile(q=0)
max_val = df['price_usd'].quantile(q=1.0)

print(min_val, Q1, median, Q3, max_val)
# Out:
# 1.0 2100.0 4800.0 8990.0 50000.0

# %%
# Quartiles
median = df['price_usd'].median()

Q1 = df['price_usd'].quantile(q=0.25)
Q3 = df['price_usd'].quantile(q=0.75)

min_val = df['price_usd'].quantile(q=0)
max_val = df['price_usd'].quantile(q=1.0)

print(min_val, Q1, median, Q3, max_val)
# Out:
# 1.0 2100.0 4800.0 8990.0 50000.0

# %%
# Rango intercuartil

iqr = Q3 - Q1

iqr
# Out:
# 6890.0

# %% [markdown]
# ### Límites para detección de outliers (datos simetricamente distribuidos)
#
# Datos entre $$Q_1 -1.5 \times \text{IQR}$$ y $$Q_3 + 1.5 \times \text{IQR}$$

# %%
minlimit = Q1 - 1.5*iqr
maxlimit = Q3 + 1.5*iqr

print(f'rango para detección de outliers: {minlimit}, {maxlimit}')
# Out:
# rango para detección de outliers: -8235.0, 19325.0

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

f, (ax_hist, ax_box) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.6, .4)})

sns.histplot(df['price_usd'], 
             ax=ax_hist, 
             color='#FA0087',
             alpha = 0.8)

sns.boxplot(df['price_usd'], 
            ax=ax_box, 
            color='#FA0087')

ax_hist.set(xlabel='')

plt.show()
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
fig1 = px.histogram(df, 
                    x="price_usd",
                    opacity=0.8, 
                    color_discrete_sequence=['#FA0087'])

fig1.update_layout(title = 'Grafica de cantidad de autos por precio',
                 font = dict(family = 'verdana', size = 16, color = 'white'),
                 template = 'plotly_dark',
                 height = 500,
                 width = 900)
fig1.show()


fig2 = px.box(df, 
              x='price_usd', 
              color_discrete_sequence=['#FA0087'])

fig2.update_layout(title = 'Grafica de cantidad de autos por precio',
                 font = dict(family = 'verdana', size = 16, color = 'white'),
                 template = 'plotly_dark',
                 height = 500,
                 width = 900)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="1e95d359-f973-4fa9-8a27-fae28527290f" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e95d359-f973-4fa9-8a27-fae28527290f")) {                    Plotly.newPlot(                        "1e95d359-f973-4fa9-8a27-fae28527290f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price_usd=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#FA0087","opacity":0.8,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":
# %% [markdown]
# Es posible calcular varios box-plot separando por una cierta variable categórica:

# %%
fig = plt.figure(figsize=(16,9))

g = sns.boxplot(x = 'engine_fuel', 
                y = 'price_usd', 
                data = df, 
                palette='Set2')

plt.show()

# %%
fig = px.box(df, 
             x='price_usd', 
             y='engine_fuel', 
             color = 'engine_fuel',
             color_discrete_sequence=px.colors.qualitative.Dark24)

fig.update_layout(title = 'Grafica de precio por tipo de combustible usado',
                  font = dict(family = 'verdana', size = 16, color = 'white'),
                  template = 'plotly_dark',
                  height = 500,
                  width = 900,
                  legend_bgcolor='rgb(117, 112, 179)')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="c8af5c53-65dc-44d0-8426-dd24db301c3e" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8af5c53-65dc-44d0-8426-dd24db301c3e")) {                    Plotly.newPlot(                        "c8af5c53-65dc-44d0-8426-dd24db301c3e",                        [{"alignmentgroup":"True","hovertemplate":"engine_fuel=%{y}<br>price_usd=%{x}<extra></extra>","legendgroup":"gasoline","marker":{"color":"#2E91E5"},"name":"gasoline","notched":false,"offsetgroup":"gasoline","orientation":"h","showlegend":true,"x":[10900.0,5000.0,2800.0,9999.0,2134.11,14700.0,3000.0,4500.0,12900.0,4200.0,6900.0,8350.0,4300.0,1666.0,8600.0,7300.0,7587.97,10950.0,12700.0,16500.0,8700.0,7500.0,8650.0,3500.0,3800.0,7200.0,1850.0,3800.0,3000.0,6200.0,3700.0,2000.0,800.0,14950.0,5350.0,17059.12,1700.0,3500.0,3000.0,8100.0,3300.0,14950.0,4490.0,2650.0,6950.0,8200.0,16500.0,8500.0,6450.0,3150.0,1900.0,4899.0,2500.0,1700.0,1800.0,12900.0,7250.0,900.0,9400.0,3300.0,8200.0,2100.0,1499.0,9800.0,2500.0,3650.0,1400.0,5400.0,12950.0,15490.0,13500.0,2000.0,7500.0,5800.0,2750.0,3299.0,1400.0,9900.0,15900.0,13500.0,3750.0,3400.0,4250.0,5500.0,4100.0,7000.0,12600.0,5400.0,14500.0,3900.0,14227.45,17000.0,3750.0,6000.0,15500.0,1900.0,6499.0,5250.0,5199.0,6000.0,6800.0,1900.0,8650.0,1565.02,16300.0,6900.0,2900.0,7000.0,4990.0,6300.0,11000.0,7000.0,3000.0,8790.0,23400.0,6800.0,6450.0,1600.0,1500.0,2300.0,5500.0,5999.0,9000.0,24900.0,6150.0,3700.0,1500.0,12999.0,12999.0,6800.0,7700.0,2800.0,22850.0,4990.0,7000.0,14000.0,3599.0,4500.0,3290.0,4200.0,8200.0,1800.0,2000.0,14300.0,1400.0,18900.0,5500.0,3799.0,1600.0,13500.0,12300.0,19500.0,14938.82,6600.0,11550.0,9050.0,19499.0,10500